# %%
import pandas as pd
import json
from sqlalchemy import create_engine

# %%
path = 'C:/Users/winyi/OneDrive/Desktop/Climate-Project/response.json'
with open(path) as input_file:
    data=json.load(input_file)

# %%
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 1535, 'limit': 1000}},
#  'results': [{'mindate': '1994-03-19',
#    'maxdate': '1996-05-28',
#    'name': 'Average cloudiness midnight to midnight from 30-second ceilometer data',
#    'datacoverage': 1,
#    'id': 'ACMC'},
#   {'mindate': '1965-01-01',
#    'maxdate': '2005-12-31',
#    'name': 'Average cloudiness midnight to midnight from manual observations',
#    'datacoverage': 1,
#    'id': 'ACMH'},
#   {'mindate': '1994-02-01',
#    'maxdate': '1996-05-28',
#    'name': 'Average cloudiness sunrise to sunset from 30-second ceilometer data',
#    'datacoverage': 1,
#    'id': 'ACSC'},
#   {'mindate': '1965-01-01',
#    'maxdate': '2005-12-31',
#    'name': 'Average cloudiness sunrise to sunset from manual observations',
#    'datacoverage': 1,
#    'id': 'ACSH'},
#   {'mindate': '1991-06-05',
#    'maxdate': '2020-09-16',
#    'name': 'Base Data',
#    'datacoverage': 0.95,
#    'id': 'ALL'},
#   {'mindate': '2010-01-01',
# ...

# %%
data_pd = pd.DataFrame(data["results"])
data_pd
# Out:
#         mindate     maxdate  \
# 0    1994-03-19  1996-05-28
# 1    1965-01-01  2005-12-31
# 2    1994-02-01  1996-05-28
# 3    1965-01-01  2005-12-31
# 4    1991-06-05  2020-09-16
# ..          ...         ...
# 995  2010-01-01  2010-12-01
# 996  2010-01-01  2010-12-01
# 997  2010-01-01  2010-12-01
# 998  2010-01-01  2010-12-01
# 999  2010-01-01  2010-12-01
#
#                                                   name  datacoverage  \
# 0    Average cloudiness midnight to midnight from 3...          1.00
# 1    Average cloudiness midnight to midnight from m...          1.00
# 2    Average cloudiness sunrise to sunset from 30-s...          1.00
# 3    Average cloudiness sunrise to sunset from manu...          1.00
# 4                                            Base Data          0.95
# ..                                                 ...           ...
# 995  Long-term averages of monthly cooling degree d...          1.00
# ...

# %%
path = 'C:/Users/winyi/OneDrive/Desktop/Climate-Project/response2.json'
with open(path) as input_file:
    data=json.load(input_file)

# %%
data_pd2 = pd.DataFrame(data["results"])
data_pd2
# Out:
#         mindate     maxdate  \
# 0    2010-01-01  2010-12-01
# 1    2010-01-01  2010-12-01
# 2    2010-01-01  2010-12-01
# 3    2010-01-01  2010-12-01
# 4    2010-01-01  2010-12-01
# ..          ...         ...
# 530  1996-07-08  2005-09-09
# 531  1996-10-21  2002-02-04
# 532  1996-07-01  2005-12-31
# 533  2010-01-01  2010-12-31
# 534  2010-01-01  2010-12-31
#
#                                                   name  datacoverage  \
# 0    Long-term averages of monthly growing degree d...           1.0
# 1    Long-term averages of monthly growing degree d...           1.0
# 2    Long-term averages of monthly growing degree d...           1.0
# 3    Long-term averages of monthly growing degree d...           1.0
# 4    Long-term averages of monthly growing degree d...           1.0
# ..                                                 ...           ...
# 530      Ash, dust, sand, or other blowing obstruction           1.0
# ...

# %%
data_combined = pd.concat([data_pd,data_pd2])
data_combined
# Out:
#         mindate     maxdate  \
# 0    1994-03-19  1996-05-28
# 1    1965-01-01  2005-12-31
# 2    1994-02-01  1996-05-28
# 3    1965-01-01  2005-12-31
# 4    1991-06-05  2020-09-16
# ..          ...         ...
# 530  1996-07-08  2005-09-09
# 531  1996-10-21  2002-02-04
# 532  1996-07-01  2005-12-31
# 533  2010-01-01  2010-12-31
# 534  2010-01-01  2010-12-31
#
#                                                   name  datacoverage  \
# 0    Average cloudiness midnight to midnight from 3...          1.00
# 1    Average cloudiness midnight to midnight from m...          1.00
# 2    Average cloudiness sunrise to sunset from 30-s...          1.00
# 3    Average cloudiness sunrise to sunset from manu...          1.00
# 4                                            Base Data          0.95
# ..                                                 ...           ...
# 530      Ash, dust, sand, or other blowing obstruction          1.00
# ...

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Climate_Project')
data_combined.to_sql('dataset_id', engine)
